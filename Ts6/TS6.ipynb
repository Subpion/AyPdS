# %% [markdown]
# #### Análisis y Procesamiento de Señales
#
# # Trabajo Práctico Nº6: Respuesta en frecuencia de Filtros Pasivos RLC
# #### Francisco Mato y Angel Joseph Vargas Martinez

# %% [markdown]
# ## analisis y discucion
# ![image.png](attachment:e4d0cf76-8c49-4a68-b265-5ce0d72a5eb5.png)
#
#
# para poder hallar la funcion tranferencia es nesesaria saber cuanto es la caida de tencion tanto en la entrada como en la salida, para calcularemos la caida de tencion en el la salida a traves del divisor de tencion asumiendo que conocemos la entrada. para ello vamos a calcular la admitancia total en los componentes en serie como en los componentes en derivacion (paralelo).
# admitancia en serie
# \begin{equation}
# y_1=\frac{1}{z_1} =\frac{d}{R} + Cas + \frac{b}{Ls}
# \end{equation}
# admitancia en derivacion
# \begin{equation}
# y_2=\frac{1}{z_2} =\frac{1-d}{R} + C(1-a)s + \frac{1-b}{Ls}
# \end{equation}
# luego expresamos el divisor de tencion en funcion de las admitancias
# \begin{equation}
# V_2=V_1*\frac{z_2}{z_1+z_2}
# \end{equation}
#
# \begin{equation}
# T(s)=\frac{V_2}{V_1}=\frac{\frac{1}{y_2}}{\frac{1}{y_1}+\frac{1}{y_2}}
# \end{equation}
#
# \begin{equation}
# T(s)=\frac{V_2}{V_1}=\frac{1}{\frac{y_1+y_2}{y_1*y_2}}*\frac{1}{y_2}
# \end{equation}
#
# \begin{equation}
# T(s)=\frac{V_2}{V_1}=\frac{y_1}{y_1+y_2}
# \end{equation}
#
# una vez hallada la exprecion de la funcion tranferencia en funcion de s procedemos a simplificarla de manera que quede como cociente de dos polinomios de grado 2
#
# \begin{equation}
# T(s)=\frac{V_2}{V_1}=\frac{\frac{d}{R} + Cas + \frac{b}{Ls}}{\frac{d}{R} + Cas + \frac{b}{Ls}+\frac{1-d}{R} + C(1-a)s + \frac{1-b}{Ls}}
# \end{equation}
#
#
# \begin{equation}
# T(s)=\frac{V_2}{V_1}=\frac{\frac{d}{R} + Cas + \frac{b}{Ls}}{\frac{1-d+d}{R} + C(1-a+a)s + \frac{1-b+b}{Ls}}
# \end{equation}
#
# \begin{equation}
# T(s)=\frac{V_2}{V_1}=\frac{\frac{d}{R} + Cas + \frac{b}{Ls}}{\frac{1}{R} + Cs + \frac{1}{Ls}}
# \end{equation}
#
# \begin{equation}
# T(s)=\frac{V_2}{V_1}=\frac{\frac{s}{C}(\frac{d}{R} + Cas + \frac{b}{Ls})}{\frac{s}{C}(\frac{1}{R} + Cs + \frac{1}{Ls})}
# \end{equation}
#
# \begin{equation}
# T(s)=\frac{V_2}{V_1}=\frac{\frac{sd}{RC} + as^2 + \frac{b}{CL}}{\frac{s}{CR} + s^2 + \frac{1}{LC}}
# \end{equation}
#
# \begin{equation}
# T(s)=\frac{V_2}{V_1}=\frac{a(\frac{sd}{aRC} + s^2 + \frac{b}{aCL})}{s^2  + \frac{s}{CR} + \frac{1}{LC}}
# \end{equation}
#
# \begin{equation}
# T(s)=\frac{V_2}{V_1}=\frac{a(s^2+\frac{s}{RC}\frac{d}{a} + \frac{1}{CL}\frac{b}{a})}{s^2 + \frac{s}{CR}  + \frac{1}{LC}}
# \end{equation}
# una vez hallada la la funcion tranferencia procedemos a escribir los parametros en funcion de los componenetes del circuito
# \begin{equation}
# w_{0p}^2=\frac{1}{LC} \quad y \quad \frac{w_{0p}}{Q_p}=\frac{1}{RC}
# \end{equation}
#
# \begin{equation}
# w_{0z}^2=\frac{1}{LC}\frac{b}{a} \quad y \quad \frac{w_{0z}}{Q_z}=\frac{1}{RC}\frac{d}{a}
# \end{equation}
#
# \begin{equation}
# k=a
# \end{equation}
# y finalmente llegamos a la funcion de tranferencia de \$T(s)$
# \begin{equation}
# T(s)=\frac{k(s^2+\frac{w_{0z}}{Q_z}s + w_{0z}^2)}{s^2 + \frac{w_{0p}}{Q_p}s + w_{0p}^2}
# \end{equation}

# %% [markdown]
# ### punto  3, 4, 5
# para darle valor a los componentes a partir de la funcion tranferencia pedida, igualamos sus coeficientes a los paramtros que estan en funcion de los componenetes, de este modo tenemos un sistema de ecuaciones lineales.
# #### (1)
# \begin{equation}
# T(s)_1=\frac{s^2+ 9 }{s^2 + s \sqrt{2}+ 1}
# \end{equation}
#
# \begin{equation}
# w_{0p}^2=\frac{1}{LC}=1 \quad y \quad \frac{w_{0p}}{Q_p}=\frac{1}{RC}=\sqrt{2}
# \end{equation}
#
# \begin{equation}
# w_{0z}^2=\frac{1}{LC}\frac{b}{a}=9 \quad y \quad \frac{w_{0z}}{Q_z}=\frac{1}{RC}\frac{d}{a}=0
# \end{equation}
#
# \begin{equation}
# k=a=1
# \end{equation}
#
# \begin{equation}
# w_{0z}^2=\frac{1}{LC}\frac{b}{1}=9 \quad y \quad \frac{w_{0z}}{Q_z}=\frac{1}{RC}\frac{d}{1}=0
# \end{equation}
#
# \begin{equation}
# b=9LC \quad y \quad d=0
# \end{equation}
# nos queda un sistema de 3 ecuaciones y 4 icognitas por lo que es un sistema compatible indeterminado, por lo que tenemos una relacion de entre los componentes para llegar a las caracteristicas pedidas del filtro
# \begin{equation}
# \left \{
# \begin{array}{rr}
# b=9LC\\
# LC=1\\
# RC=\sqrt{2}
# \end{array}
# \right .
# \end{equation}
# para el analisis de polos y zeros, nesesitamos calcular las raices del polinomio del denominador y la del numerador, de este modo hallamos que hay dos polos en $ 1*e^{\frac{3\pi}{4}}$ y en  $1*e^{\frac{5\pi}{4}}$ por lo que estan en el radio unitario, luego los zeros se ubican en $-3j$ y $3j$ por lo que el diagrama de polos y zeros queda:

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

fig, ax = plt.subplots()

circle = plt.Circle((0, 0), 1, color='blue', fill=False, linestyle='--', linewidth=2)


ax.add_artist(circle)
polos=([-np.sqrt(2)/2+np.sqrt(2)*1j/2,-np.sqrt(2)/2-np.sqrt(2)*1j/2])
zeros=([3j,-3j])
plt.figure(1)

plt.plot(np.real(polos[0]), np.imag(polos[0]), 'x', markersize=10, label='Polos',color="r")
plt.plot(np.real(polos[1]), np.imag(polos[1]), 'x', markersize=10,color="r")

plt.plot(np.real(zeros[0]), np.imag(zeros[0]), 'o', markersize=10, label='zeros', fillstyle='none',color="b")
plt.plot(np.real(zeros[1]), np.imag(zeros[1]), 'o', markersize=10,fillstyle='none',color="b")
plt.axhline(0, color='k', lw=0.5)
plt.axvline(0, color='k', lw=0.5)

plt.xlim(-2,1)
plt.ylim(-4,4)
ax.axhline(0, color='black')
ax.axvline(0, color='black')
ax.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# luego proseguimos a analizar el modulo en respuesta de frecuencia de la funcion tranferencia, para ello evaluamos en $s=jw$ por lo que queda la funcion tranferencia igual a:
# \begin{equation}
# T(jw)_1=\frac{(jw)^2+ 9 }{(jw)^2 + jw \sqrt{2}+ 1}
# \end{equation}
# \begin{equation}
# T(jw)_1=\frac{-w^2+ 9 }{-w^2 + jw \sqrt{2}+ 1}
# \end{equation}
# y tomamos modulos tanto en denominador como numerador
# \begin{equation}
# |T(jw)_1|=\frac{|-w^2+ 9| }{|-w^2 + jw \sqrt{2}+ 1|}
# \end{equation}
#
# \begin{equation}
# |T(jw)_1|=\frac{|-w^2+ 9| }{\sqrt{(-w^2+1)^2 + (w \sqrt{2})^2}}
# \end{equation}
# si graficamos el modulo en funcion de la frecuencia en radianes obtenemos:

# %%
w=np.arange(0,10,0.1)
t_1=((-w**2)+9)/(-w**2+np.sqrt(2)*w*(1j)+1)
plt.plot(w, np.abs(t_1))
plt.title('Respuesta en Magnitud')
plt.xlabel('frecuencia angular [rad/s]')
plt.ylabel('|T(jω)|')
plt.axhline(1,linestyle="--",color="r")
plt.grid(True, which='both', ls=':')
plt.show()

# %% [markdown]
# luego calulamos la fase
# \begin{equation}
# T(jw)_1=\frac{(jw)^2+ 9 }{(jw)^2 + jw \sqrt{2}+ 1}
# \end{equation}
# \begin{equation}
# T(jw)_1=\frac{-w^2+ 9 }{-w^2 + jw \sqrt{2}+ 1}
# \end{equation}
# \begin{equation}
# T(jw)_1=\frac{-w^2+ 9 }{-w^2 + jw \sqrt{2}+ 1}\frac{-w^2 + 1 - jw \sqrt{2}}{-w^2 + 1 - jw \sqrt{2}}
# \end{equation}
# \begin{equation}
# T(jw)_1=\frac{(-w^2+ 9)(-w^2 + 1 - jw \sqrt{2}) }{(-w^2+1)^2 + (w \sqrt{2})^2}
# \end{equation}
#
# \begin{equation}
# T(jw)_1=\frac{(-w^2+ 9)(-w^2 + 1) - (jw \sqrt{2})(-w^2+ 9) }{(-w^2+1)^2 + (w \sqrt{2})^2}
# \end{equation}
# \begin{equation}
# T(jw)_1=\frac{(-w^2+ 9)(-w^2 + 1)}{(-w^2+1)^2 + (w \sqrt{2})^2}-j\frac{(w \sqrt{2})(-w^2+ 9) }{(-w^2+1)^2 + (w \sqrt{2})^2}
# \end{equation}
# \begin{equation}
# \angle{T(jw)_1}=-tg^{-1}(\frac{w \sqrt{2}}{-w^2 + 1})
# \end{equation}
# luego lo graficamos y obtenemos que:

# %%
plt.plot(w, np.angle(t_1))
plt.title('Fase')
plt.xlabel('frecuencia angular [rad/s]')
plt.ylabel('Fase [°]')
plt.grid(True, which='both', ls=':')
plt.show()

# %% [markdown]
# #### (2)
#
# \begin{equation}
# T(s)_2=\frac{s^2+ \frac{1}{9} }{s^2 + s \frac{1}{5}+ 1}
# \end{equation}
#
# \begin{equation}
# w_{0p}^2=\frac{1}{LC}=1 \quad y \quad \frac{w_{0p}}{Q_p}=\frac{1}{RC}=\frac{1}{5}
# \end{equation}
#
# \begin{equation}
# w_{0z}^2=\frac{1}{LC}\frac{b}{a}=\frac{1}{9} \quad y \quad \frac{w_{0z}}{Q_z}=\frac{1}{RC}\frac{d}{a}=0
# \end{equation}
#
# \begin{equation}
# k=a=1
# \end{equation}
# \begin{equation}
# \left \{
# \begin{array}{rr}
# b=\frac{LC}{9}\\
# LC=1\\
# RC=5
# \end{array}
# \right .
# \end{equation}
# luesgo procedemos a hacer el mismo analisis que hicimos para la primera funcion de tranferencia. buscando los polos y zeros hallamos que $T(s)_2$ tiene polos en

# %%
fig, ax = plt.subplots()


circle = plt.Circle((0, 0), 1, color='blue', fill=False, linestyle='--', linewidth=2)
ax.add_artist(circle)

polos=([-1/10+3*np.sqrt(11)*1j/10,-1/10-3*np.sqrt(11)*1j/10])
zeros=([(1j/3),-(1j/3)])
plt.figure(1)

plt.plot(np.real(polos[0]), np.imag(polos[0]), 'x', markersize=10, label='Polos',color="r")
plt.plot(np.real(polos[1]), np.imag(polos[1]), 'x', markersize=10,color="r")

plt.plot(np.real(zeros[0]), np.imag(zeros[0]), 'o', markersize=10, label='zeros', fillstyle='none',color="b")
plt.plot(np.real(zeros[1]), np.imag(zeros[1]), 'o', markersize=10,fillstyle='none',color="b")
plt.axhline(0, color='k', lw=0.5)
plt.axvline(0, color='k', lw=0.5)

plt.xlim(-2,1)
plt.ylim(-4,4)
ax.axhline(0, color='black')
ax.axvline(0, color='black')
ax.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# luego buscamos el modulo de la funcion tranferencia por lo que hacemos el mismo procedimiento antes hecho para la funcion tranferencia del punto 1:
# \begin{equation}
# T(jw)_1=\frac{(jw)^2+ \frac{1}{9} }{(jw)^2 + jw \frac{1}{5}+ 1}
# \end{equation}
# \begin{equation}
# T(jw)_1=\frac{-w^2+ \frac{1}{9} }{-w^2 + jw \frac{1}{5}+ 1}
# \end{equation}
# y tomamos modulos tanto en denominador como numerador
# \begin{equation}
# |T(jw)_1|=\frac{|-w^2+ \frac{1}{9}| }{|-w^2 + jw \frac{1}{5}+ 1|}
# \end{equation}
#
# \begin{equation}
# |T(jw)_1|=\frac{|-w^2+ \frac{1}{9}| }{\sqrt{(-w^2+1)^2 + (w \frac{1}{5})^2}}
# \end{equation}

# %%
w=np.arange(0,10,0.1)
t_1=((-w**2)+1/9)/(-w**2+(1/5)*w*(1j)+1)
plt.plot(w, np.abs(t_1))
plt.title('Respuesta en Magnitud')
plt.xlabel('frecuencia angular [rad/s]')
plt.ylabel('|T(jω)|')
plt.axhline(1,linestyle="--",color="r")
plt.grid(True, which='both', ls=':')
plt.show()

# %% [markdown]
# luego calulamos la fase
# \begin{equation}
# T(jw)_1=\frac{(jw)^2+ \frac{1}{9} }{(jw)^2 + jw \frac{1}{5}+ 1}
# \end{equation}
# \begin{equation}
# T(jw)_1=\frac{-w^2+ \frac{1}{9} }{-w^2 + jw \frac{1}{5}+ 1}
# \end{equation}
# \begin{equation}
# T(jw)_1=\frac{-w^2+ \frac{1}{9} }{-w^2 + jw \frac{1}{5}+ 1}\frac{-w^2 + 1 - jw \frac{1}{5}}{-w^2 + 1 - jw \frac{1}{5}}
# \end{equation}
# \begin{equation}
# T(jw)_1=\frac{(-w^2+ \frac{1}{9})(-w^2 + 1 - jw \frac{1}{5}) }{(-w^2+1)^2 + (w \frac{1}{5})^2}
# \end{equation}
#
# \begin{equation}
# T(jw)_1=\frac{(-w^2+ \frac{1}{9})(-w^2 + 1) - (jw \frac{1}{5})(-w^2+ \frac{1}{9}) }{(-w^2+1)^2 + (w \frac{1}{5})^2}
# \end{equation}
#
# \begin{equation}
# T(jw)_1=\frac{(-w^2+ \frac{1}{9})(-w^2 + 1)}{(-w^2+1)^2 + (w \frac{1}{5})^2}-j\frac{(w \frac{1}{5})(-w^2+ \frac{1}{9}) }{(-w^2+1)^2 + (w \frac{1}{5})^2}
# \end{equation}
#
# \begin{equation}
# \angle{T(jw)_1}=-tg^{-1}(\frac{w \frac{1}{5}}{-w^2 + 1})
# \end{equation}

# %%
plt.plot(w, np.angle(t_1))
plt.title('Fase')
plt.xlabel('frecuencia angular [rad/s]')
plt.ylabel('Fase [°]')
plt.axhline(0,linestyle="--",color="r")
plt.grid(True, which='both', ls=':')
plt.show()

# %% [markdown]
# #### (3)
# \begin{equation}
# T(s)_1=\frac{s^2+ s \frac{1}{5}+ 1 }{s^2 + s \sqrt{2}+ 1}
# \end{equation}
#
# \begin{equation}
# w_{0p}^2=\frac{1}{LC}=1 \quad y \quad \frac{w_{0p}}{Q_p}=\frac{1}{RC}=\sqrt{2}
# \end{equation}
#
# \begin{equation}
# w_{0z}^2=\frac{1}{LC}\frac{b}{a}=1 \quad y \quad \frac{w_{0z}}{Q_z}=\frac{1}{RC}\frac{d}{a}=\frac{1}{5}
# \end{equation}
#
# \begin{equation}
# k=a=1
# \end{equation}
#
# \begin{equation}
# \left \{
# \begin{array}{rr}
# b=LC\\
# LC=1\\
# RC=\sqrt2\\
# d=\frac{RC}{5}
# \end{array}
# \right .
# \end{equation}

# %%
fig, ax = plt.subplots()

circle = plt.Circle((0, 0), 1, color='blue', fill=False, linestyle='--', linewidth=2)


ax.add_artist(circle)
polos=([-np.sqrt(2)/2+np.sqrt(2)*1j/2,-np.sqrt(2)/2-np.sqrt(2)*1j/2])
zeros=([-1/10+3*np.sqrt(11)*1j/10,-1/10-3*np.sqrt(11)*1j/10])
plt.figure(1)

plt.plot(np.real(polos[0]), np.imag(polos[0]), 'x', markersize=10, label='Polos',color="r")
plt.plot(np.real(polos[1]), np.imag(polos[1]), 'x', markersize=10,color="r")

plt.plot(np.real(zeros[0]), np.imag(zeros[0]), 'o', markersize=10, label='zeros', fillstyle='none',color="b")
plt.plot(np.real(zeros[1]), np.imag(zeros[1]), 'o', markersize=10,fillstyle='none',color="b")
plt.axhline(0, color='k', lw=0.5)
plt.axvline(0, color='k', lw=0.5)

plt.xlim(-2,1)
plt.ylim(-4,4)
ax.axhline(0, color='black')
ax.axvline(0, color='black')
ax.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# \begin{equation}
# T(jw)_1=\frac{(jw)^2+ jw \frac{1}{5}+ 1 }{(jw)^2 + (jw) \sqrt{2}+ 1}
# \end{equation}
#
# \begin{equation}
# T(jw)_1=\frac{-(w)^2+ jw \frac{1}{5}+ 1 }{-(w)^2 + (jw) \sqrt{2}+ 1}
# \end{equation}
#
# \begin{equation}
# T(jw)_1=\frac{-(w)^2+ jw \frac{1}{5}+ 1 }{-(w)^2 + (jw) \sqrt{2}+ 1}
# \end{equation}
#
# \begin{equation}
# |T(jw)_1|=\frac{|-(w)^2+ jw \frac{1}{5}+ 1| }{|-(w)^2 + (jw) \sqrt{2}+ 1|}
# \end{equation}
#
# \begin{equation}
# |T(jw)_1|=\frac{\sqrt{(-w^2+1)^2 + (w \frac{1}{5})^2}}{\sqrt{(-w^2+1)^2 + (w \sqrt{2})^2}}
# \end{equation}

# %%
w=np.arange(0,10,0.1)
t_1=((-w**2)+w*(1/5)*(1j) +1)/(-w**2+np.sqrt(2)*w*(1j)+1)
plt.plot(w, np.abs(t_1))
plt.title('Respuesta en Magnitud')
plt.xlabel('frecuencia angular [rad/s]')
plt.ylabel('|T(jω)|')
plt.axhline(1,linestyle="--",color="r")
plt.grid(True, which='both', ls=':')
plt.show()

# %% [markdown]
# \begin{equation}
# T(jw)_1=\frac{(jw)^2+ jw \frac{1}{5}+ 1 }{(jw)^2 + (jw) \sqrt{2}+ 1}
# \end{equation}
#
# \begin{equation}
# T(jw)_1=\frac{(jw)^2+ jw \frac{1}{5}+ 1 }{(jw)^2 + (jw) \sqrt{2}+ 1}*\frac{(jw)^2 - (jw) \sqrt{2}+ 1 }{(jw)^2 - (jw) \sqrt{2}+ 1}
# \end{equation}
#
#
# \begin{equation}
# T(jw)_1=\frac{(-(w)^2+ 1+ jw \frac{1}{5} )(-(w)^2 + 1 - (jw) \sqrt{2})}{(-w^2+1)^2 + (w \sqrt{2})^2}
# \end{equation}
#
# \begin{equation}
# T(jw)_1=\frac{(-(w)^2+ 1)(-(w)^2 + 1)-(-(w)^2+ 1)(jw)+(jw \frac{1}{5})((w)^2 + 1) +(w) \frac{1}{5})(w) \sqrt{2})}{(-w^2+1)^2 + (w \sqrt{2})^2}
# \end{equation}
#
# \begin{equation}
# T(jw)_1=\frac{(-(w)^2+ 1)(-(w)^2 + 1)+(w \frac{1}{5})(w) \sqrt{2}}{(-w^2+1)^2+ (w \sqrt{2})^2}+j
# \frac{(-(w)^2+ 1)(w)+(w \frac{1}{5})((w)^2 + 1)}{(-w^2+1)^2 + (w \sqrt{2})^2}
# \end{equation}

# %% [markdown]
# \begin{equation}
# \angle{T(jw)_1}=tg^{-1}(\frac{(-(w)^2+ 1)(w)+(w \frac{1}{5})((w)^2 + 1)}{(-(w)^2+ 1)(-(w)^2 + 1)+(w \frac{1}{5})(w) \sqrt{2}})
# \end{equation}

# %%
plt.plot(w, np.angle(t_1))
plt.title('Respuesta en fase')
plt.xlabel('frecuencia [rad/s]')
plt.ylabel('∠T(jω)')
plt.axhline(0.1,linestyle="--",color="r")
plt.grid(True, which='both', ls=':')
plt.show()

# %% [markdown]
# ## conclusiones

# %% [markdown]
# el analisis de los filtros nos resulta util a la hora de ver que frecuencias pasan por este ultimo, siendo que el analisis de la funcion tranferencia en modulo nos ayuda a poder ver cuales frecuencias son pasan y cuales corta a partir de atenuarlas, mientras que con el analisis de fase poddemos preveer que tan demorada va a estar la señal filtrada cojn respecto a la original(esto se veria mejor en el analis de demora de grupo la, la cual es la derivdad de la fase).
# como se ve en los grafico cada filtro tiene una respuesta diferente en frecuencia la cual podemos encarjala en una categria. la $T_1$  tiene una frecuencia de corte de 3 rad/s, y presenta una asintota horizontal en en 1 esto quiere decir que deja pasar frecuencia mayores y menores a 3 pero frecuencia cercanas a 3 son atenuadas.
# si analisamos $T_2$, podemos observar que la respuesta en frecuencia del modulo tiene deja pasar frecuencia mayores a la frecuencia de corte(1rad/s) y no deja pasar frecuencia menores a esta por lo que es un pasa alto
# y por ultimo la $T_3$,semejante a la $T_1$ sumprime bandas cercanas a la frecuencia de corte por lo que justamente es un sumpime banda.
